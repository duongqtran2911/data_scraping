# %%
import json
import pandas as pd
from pymongo import MongoClient
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# MongoDB connection setup
mongo_uri = "mongodb://dev-valuemind:W57mFPVT57lt3wU@10.10.0.42:27021/?replicaSet=rs0&directConnection=true&authSource=assets-valuemind"

# Connect to MongoDB and fetch documents
client = MongoClient(mongo_uri)
db = client["assets-valuemind"]
collection = db["test"]
data_from_mongo = list(collection.find({}))  # You can add filters here if needed

# %%
# data_from_mongo

# %%
records = []

for datapoint in data_from_mongo:
    # print(f"datapoint:\n{datapoint}\n")

    compare_list = datapoint.get("assetsCompareManagements", [])
    # print(f"compare_list:\n{len(compare_list)}\n")

    for item in compare_list:
        
        am = item.get("assetsManagement", {})
        # print(f"am:\n {am}\n")
        basic_info = am.get("basicAssetsInfo", {})
        # print(f"basic_info:\n{len(basic_info)}\n")
        geo = am.get("geoJsonPoint", {})
        

        record = {
            # "profileId": item.get("profileId"),
            # "assetsCompareId": item.get("assetsCompareId"),
            'address': basic_info.get("basicAddressInfo", {}).get("fullAddress"),
            "isCompare": item.get("isCompare", False),
            # "status": am.get("status"),
            "area": basic_info.get("area"),
            "width": basic_info.get("width"),
            "height": basic_info.get("height"),
            "percentQuality": basic_info.get("percentQuality"),
            "landPrice": basic_info.get("landPrice"),
            "lat": geo.get("y"),
            "lon": geo.get("x"),
            "legalStatus": item.get("legalStatus", {}).get("description"),
            "location": item.get("location", {}).get("description"),
            "traffic": item.get("traffic", {}).get("description"),
            "population": item.get("population", {}).get("description"),
            "shape": item.get("shape", {}).get("description"),
            "other": item.get("other", {}).get("description"),
        }
        records.append(record)

df = pd.DataFrame(records)
# print(df.head())

# %%
print(df.columns)
df.shape
# Out:
# Index(['address', 'isCompare', 'area', 'width', 'height', 'percentQuality',
#        'landPrice', 'lat', 'lon', 'legalStatus', 'location', 'traffic',
#        'population', 'shape', 'other'],
#       dtype='object')
# (36348, 15)

# %%
df.head(5)
# Out:
#                                              address  isCompare   area  width  \
# 0  Thửa đất số 2 (pcl); 3; 193; 194, tờ bản đồ số...      False  592.7  18.42
# 1  Thửa đất số 10106, tờ bản đồ số 4, xã Long Hậu...       True  112.0    5.5
# 2  Thửa đất số 79, tờ bản đồ số 7, ấp 4, xã Long ...       True   83.0    4.1
# 3  Thửa đất số 10328, tờ bản đồ số 4, xã Long Hậu...       True  115.0    7.0
# 4  TĐS 43, TBĐS 168 - 300 Lê Trọng Tấn, phường Tâ...      False  490.9    3.7
#
#    height  percentQuality     landPrice        lat         lon  legalStatus  \
# 0   62.09             NaN           NaN  10.633147  106.690064  Có GCN QSDĐ
# 1   29.00             NaN  4.046693e+07  10.641189  106.688829  Có GCN QSDĐ
# 2   30.50             NaN  4.593301e+07  10.643927  106.688596  Có GCN QSDĐ
# 3   27.00             NaN  4.514851e+07  10.641385  106.688727  Có GCN QSDĐ
# 4   31.11             0.7  0.000000e+00  10.807799  106.622273  Có GCN QSDĐ
#
#                        location  \
# 0                       ĐT 826C
# 1                       ĐT 826C
# 2   ĐT 826C và đường bê tông 4m
# 3                       ĐT 826C
# 4  Mặt tiền đường Lê Trọng Tấn
#
#                                              traffic population  \
# 0                               Nhựa rộng khoảng 10m   Đông đúc
# 1                               Nhựa rộng khoảng 10m   Đông đúc
# 2                               Nhựa rộng khoảng 10m   Đông đúc
# 3                               Nhựa rộng khoảng 10m   Đông đúc
# 4  Đường nhựa rộng khoảng 25m (lề mỗi bên rộng kh...   Đông đúc
#
#                  shape     other
# 0              Đa giác  Không có
# 1  Tương đối vuông vức       nan
# 2  Tương đối vuông vức       nan
# 3  Tương đối vuông vức       nan
# 4           Hình chữ L  Không có

# %%
df.iloc[0, :]
# Out:
# address           Thửa đất số 2 (pcl); 3; 193; 194, tờ bản đồ số...
# isCompare                                                     False
# area                                                          592.7
# width                                                         18.42
# height                                                        62.09
# percentQuality                                                  NaN
# landPrice                                                       NaN
# lat                                                       10.633147
# lon                                                      106.690064
# legalStatus                                             Có GCN QSDĐ
# location                                                    ĐT 826C
# traffic                                        Nhựa rộng khoảng 10m
# population                                                 Đông đúc
# shape                                                       Đa giác
# other                                                      Không có
# Name: 0, dtype: object

# %%
# Select relevant features
features_numerical = ["area", "width", "height", "percentQuality", "landPrice", "lat", "lon"]
features_categorical = ["legalStatus", "shape", "other"]
features_all = features_numerical + features_categorical

# %%
sum(pd.isna(df["lon"]))
# Out:
# 36333

# %%
print(f"number of unique values: {df["legalStatus"].nunique()}")
for i in (df["legalStatus"].unique()):
    print(i)
# Out:
# number of unique values:, 49
# Có GCN QSDĐ
# Có GCNQSDĐ
# Đã có GCN QSDĐ lâu dài (giả định)
# Chưa có GCN QSDĐ, lâu dài (giá bán 95% căn hộ)
# Chưa có GCN QSDD, GCN lâu dài (giá bán 100% căn hộ)
# Chưa có GCN QSDĐ, (giá bán 95% căn hộ)
# Chưa có GCN QSDĐ, (giá bán 100% căn hộ)
# 0
# Chưa có GCN QSDD (giá bán 100% căn hộ)
# nan
# 0.0
# Giá bán bao gồm phí cấp GCN QSDĐ lâu dài
# GCN QSDD
# HĐMB
# Hợp đồng mua bán
# Hợp đồng mua bán, giá bán bao phí ra GCN QSDĐ
# Hợp đồng mua bán (giá bán bao gồm 5% bao ra sổ)
# Đã có GCN QSDĐ
# Chưa có GCN QSDĐ, thời hạn sử dụng đất lâu dài (giá bán chưa bao gồm 5% giá trị hợp đồng để cấp GCN QSDĐ)
# Chưa có GCN QSDĐ, thời hạn sử dụng đất lâu dài (giá bán đã bao gồm 5% giá trị hợp đồng để cấp GCN QSDĐ)
# Giá bán bao gồm phí cấp GCN QSDĐ
# Chưa có GCN QSDĐ, (giá bán 97% căn hộ)
# Chưa có GCN QSDĐ, GCN lâu dài (giá bán 95% căn hộ)
# GCN QSDĐ
# Hợp đồng mua bán (giá bán bao gồm tất cả chi phí để cấp GCN QSDĐ)
# HDMB
# Chưa có GCN QSDĐ
# Có GCN QSDD
# GCNQSDĐ
# Hợp đồng mua bán (giá bán chưa bao gồm 5% bao ra sổ)
#  GCNQSDĐ
# HĐMB, giá đã bao GCN QSDĐ
# None
# Có GCN QSDĐ
# Sổ đỏ lâu dài
# Có HĐMB
# Giấy CNQSDĐ
# HĐMB (Bao thuế phí sang tên làm GCNQSDĐ)
# Chưa có GCN QSDĐ
# Có GCN QSDĐ, đất thuê trả tiền một lần
# Có GCN QSDĐ, đất giao
# Không có GCNQSDĐ
# Sổ đồng sở hữu, diện tích nhỏ chưa tách sổ được
# 1
# Không có GCN
# Có 1/500
# HĐMB ( giá bán có sổ)
# Chưa có GCN QSDĐ, giá bán bao ra sổ
# HĐMB (chưa bao gồm 5% sổ)
# Công chứng vi bằng

# %%
for i in (df["shape"].unique()):
    print(i)
# Out:
# Đa giác
# Tương đối vuông vức
# Hình chữ L
# Vuông vức
# Không vuông vức
# Chữ T
# Hình Phiễu
# 0
# Hình chữ T, khoảng 55% đất bị che khuất
# Đa giác nhiều góc cạnh
# None
# Tương đối
# Chữ W
# Chữ L
# nan
# Không vuông vức, một phần thửa đất bị che khuất
# Hình đa giác, không vuông vức
# 0.0
# Không vuông vức, tóp hậu
# Tương đối vông vức
# Tương đối vuông vức (Nở hậu)
# Tương đối v uông vức
# Hình đa giác nhiều góc cạnh
# Hình đa giác
# Nở hậu
# Tương đối vuông vức, mặt tiền bị hẹp
# Tương đối vuông vức, mặt tiền hẹp, phần đất phía sau bi khuất
# Khá vuông vức
# Hình đa giác tương đối vuông vức
# Hình chữ L, tóp hậu
# Hình đa giác, nở hậu
# Đa giác nhiều góc cạnh, tóp hậu
# Kém vuông vức
# Hình chữ T
# Đa giác, không vuông vức
# Hình cổ chai
# Không vuông vức, 1 phần đất bị che khuất
# Tương đối vuông vức,  phần lớn đất bị che khuất
# Tương đối vuông vức, phần lớn đất bị che khuất
# Tương đối vuông vức
# vuông vức
# Chữ L, tóp hậu
# Hình đa giác, phần lớn đất bị che khuất
# Đa giác (tóp hậu)
# Hình chữ T, khoảng 90% đất bị che khuất
# Hình chữ L, khoảng 70% đất bị che khuất
# Tóp hậu (mặt trước rộng khoảng 11m, mặt sau rộng khoảng 4m)
# Hình chữ L, được hợp khối từ 3 thửa đất
# Hình chữ L, khoảng 30% đất bị che khuất
# Tóp hậu còn 9m
# Hình chữ L, nở hậu
# Hình chữ L, khoảng 55% diện tích bị che khuất
# Tóp hậu
# Vạt góc
# Đa giác (phần lớn bị che khuất)
# Hình tam giác
# Tương đối vuông
# Hình đa giác nhiều góc cạnh, mặt tiền nhỏ, phần lớn đất bị che khuất
# Hình đa giác lòi lõm
# Dân cư tương đối
# Mặt tiền xéo với mặt đường, không vuông vức
# Khoảng 75% diện tích đất bị che khuất
# Nở hậu hình chữ L
# Tương đối vuông vức, nở hậu
# Mặt tiền hẹp, phần đất phía sau bị che lấp
# Mặt tiền hẹp, phần lớn đất bị che khuất
# Tương đối vuông vức, mặt tiền bị vạt góc
# Hình lục giác
# Mặt tiền hẹp, phần đất phía sau bị che lấp, đa giác
# Tương đương vuông vức
# Đa giác (nở hậu)
# tương đối vuông vức
# Đa giác, phần lớn đất bị che khuất
# Tương đối vuông vức, tóp hậu
# Tương đối vuông vức, mặt tiền hẹp, phần đất phía sau bị che lấp
# Một phần đất phía sau là ao trũng chưa được san lấp
# Đã san lấp
# chữ L
# Không vuông vức, phần lớn thửa đất bi che khuất
#  Vuông vức
# Tam giác, phần lớn diện tích bị che khuất
# Hình chữ L, bị che khuất khoảng 60%
# Tương đối vuông vức, mặt tiền hẹp vì bị thửa đất khác che khuất
# Đa giác bất cân xứng, phần lớn đất bị che khuất
# Đa giác tương đối cân xứng
# Đa giác hẹp dài, nằm ngang
# Khu đô thị đã xây nhà hoàn thiện mặt ngoài, chưa có dân cư sinh sống
# Không vuông vức, phần lớn thửa đất bị che khuất
# Nội khu
# Đa giác đa phần bị che khuất
# Chữ L, 1 phần diện tích bị che khuất
# Hình chữ L, phần hậu có tiếp giáp hẻm 1/ (đang thuộc QH đất GD)
# Phần đất phía sau bị che khuất 17,21m
# Tóp hậu, tương đối vuông vức
# Không vuông vức, phần lớn mặt tiền bị che khuất
# Hình con dao
# Kém vuông vức, bị khuyết nhiều đất
# Tương dối vuông vức
# Đa giác vuông vức
# Tam giác
# Vuông vức
# hình chữ L
# Con dao
# Đa giác
# đa giác
# Vuông vức, phần lớn đất bị che khuất
# Hình chữ L, phần lớn đất bị che khuất
# Kém vuông vức, loang lổ
# Kém vuông vức, bị khuyết 02 thửa đất bên trong
# Tương đối vuông vức (nở hậu)
# Mặt tiền giáp đường hẹp, phần đất phía sau bị che khuất
# Đa giác ít vuông vức
# Đa giác vuông vức ít
# đa giác vuông vức
# Đa giác (hình chữ L)
# Hình thang, nở hậu
# đa góc cạnh/ tam giác
# Đa giác (không tính phần hành lang bảo vệ an toàn sông sẽ chỉ còn hình tam giác)
# Hình chữ L, có khoảng 50% diện tích không tiếp giáp
# Đa giác vuông vức, có khoảng 70% diện tích không tiếp giáp đường
# Đa giác vuông vức, có khoảng 90% diện tích không tiếp giáp đường
# Mặt tiền bị vạt góc
# Hình đa giác, tóp hậu
# Chữ L (nở hậu)
# Hình đa giác nhiều góc cạnh, khoảng 70% đất bị che khuất
# Tương đối vuông
# Ngũ giác (xéo 1 góc)
# Đa giác, nhiều góc cạnh
# Hình thang vuông
# 3PN, 2WC
# Chữ T, phần lớn diện tích bị che khuất
# Tương đối vuông (mặt tiền hẹp)
# Tương đối vuông vức (tóp hậu)
# 2PN, 1WC
# 1PN, 1WC
# Khu đô thị đã xây nhà và hạ tầng hoàn thiện, chưa có nhiều dân cư sinh sống
# Phần lớn mặt tiếp giáp hẻm bị che khuất
# Tương đối vuông vức, phần lớn mặt tiếp giáp hẻm bị che khuất
# Đa giác nhiều cạnh, phía sau bị khuyết đường cung tròn vào thửa đất, trên đất có ao nhỏ
# Đa giác nhiều cạnh
# Vuông vức, khoảng 90% đất bị che khuất
# Nở hậu 14m
# Chữ L phần lớn đất bị che khuất
#  Tương đối vuông vúc
# Hình dáng nhiều góc cạnh, phần lớn diện tích đất nằm khuất bên trong
# Hình dáng nhiều góc cạnh
# Tương đối cân xứng
# Tương đối vuông vức, phần lớn đất bị che khuất và chỉ có khoảng 4,52m tiếp giáp mặt tiền đường
# Tương đối vuông, phần đất lớn diện tích 1.680,20m² bị che khuất và chỉ có khoảng 5,07m tiếp giáp mặt tiền đường
# Hình đa giác nhiều góc cạnh, phần đất lớn diện tích đất bị che khuất và chỉ có khoảng 38,5m tiếp giáp mặt tiền đường
# Tương đối vuông vức, phần lớn đất bị che khuất và chỉ có khoảng 3,5m tiếp giáp mặt tiền đường
# Tương đối vuông vức, phần lớn đất bị che khuất và chỉ có khoảng 3m tiếp giáp mặt tiền đường
# Không cân xứng
# Tương đối vuông, chiều rộng là 17,55 nhưng bị mảnh đất khác che khuất nên chiều rộng mặt tiền còn 2,81m
# Tương đối vuông vức, phần lớn đất bị che khuất và chỉ có khoảng 2,81m tiếp giáp mặt tiền đường
# Hình đa giác, bất cân đối
# Hình chữ L, nở hậu bên trong tương đối vuông vức
# tương đối vuông, tóp hậu
# tương đối vuông, nở hậu
# Hình đa giác, kém cân đối
# Hình đa giác, cân đối hơn TSTĐG
# 68.1
# Không cân đối
# Đa giác, không vuông vắn
# Không vuông vức, đẹp hơn TSTĐ
# Không vuông vắn
# Khá vuông vắn
# Tương đồng
# Hình chữ nhật
# Tương đối vuông, gần nửa phần đất bị khuất sau hộ dân khác
# Chiều sâu lớn
# Đa giác, zic zắc
# Hình thang, thóp hậu
# Tương đối vuông, một nửa đất bị che khuất
# Tương đối vuông, bị bao quanh bởi 3 mặt cống đã lắp nắp bê tông rộng khoảng 2m
# Vuông vức, nở hậu
# Không vuông vức, đất bị che khuất 1 phần
# không vuông vắn
# Vuông vắn
# Tương đối cân
# Thiếu cân đối
# Không vuông vức, nở hậu
# Không vuông vức, một phần mặt tiền đường bị che khuất bởi thửa đất khác
# Hình phiễu
# Khá vuông vức, nở hậu
# Hình đa giác, tương đối vuông vức
# Kém vuông hơn TSTĐ
# Hình dáng đa giác, bị che khuất
# Hình dáng đa giác
# Khu vực không có dân cư
# Dân cư tập trung tương đối
# Dân cư tập trung tương đối vắng
# Kém vuông
# Tương đồng TSTĐG
# Hình chữ T, phần mặt tiến tiếp giáp đường 4m
# Khá vuông văn
# Vuong vắn
# Tương đồng
# Hình chữ L
# Không được vuông vức
# Lối vào hẹp khoảng 4,8m, diện tích đất phần lớn bị che khuất
# Đa giác, đất bị che khuất một phần lớn
# Đa giác, đất chỉ có đường đi vào, không tiếp giáp đường, bị che khuất
# Đa giác, cơ sở hạ tầng hoàn thiện
# Vuông vức, bằng phẳng
# Tương đối vuông, bằng phẳng
# Không vuông vức, có suối xung quanh
# Không vuông vức, có mương nước
# Không vuông vức, có mương nước, view hồ
# Bình thường
# Hình đa giác, không cân đối
# Hình đa giác, không cân đối, tóp 7m tại giữa
# Đa giác, không cân đối
# 34
# Hình tam giác, không cân đối
# Hình dáng không vuông vức
# Tương đôi vuông vức
# 8251603.999999999
# Tương đối vuông, hình chữ L
# Không vuông, tóp hậu
# Đa giác, không cân đối, đường đâm
# Đa giác, không cân đối, có kênh nước đi ngang qua đất
# Tương đối vuông vức, cuối đất hình đa giác
# Đường vào hẹp, không vuông vức
# Hình chữ T ngược, phần lớn đất nằm ở phía sau
# Chỉ có 240m²
# Chỉ có 240m² đất tiếp giáp mặt tiền, phần còn lại bị khuất phía sau
# Đất nở hậu
# Tương đối vuông vức, mặt tiền rộng
# Vuông vức, mặt tiền rộng
# Không vuông vức, có đường vào đất, đất bị che khuất, không tiếp giáp nhiều với mặt đường
# Không vuông vức, phần lớn đất bị che khuất
# Không vuông vức, mặt tiền rộng
# Không vuông vức, đất chỉ có đường vào, có mương trước đất, phần lớn đất bị che khuất
# Kém vuông vức, tóp hậu
# Hình đa giác chữ nhật dài
# Hình đa giác, đường vào hẹp
# Hình chữ nhật dài
# Tương đối vuông vức
#  không vuông vức
# Không vuông vức, một phần bị che khuất bởi thửa đất khác và khuất một phần chính giữa đất bởi thửa đất khác
# Hình đa giác không cân đối, phần lớn đất bị che khuất, chỉ có 9m giáp đường
# Hình đa giác, chỉ có đường vào đất, đất bi che khuất
# ONT + LUK
# Không vuông vức, một phần đất bị che khuất
# Tóp hậu, hình đa giác, nhiều góc cạnh
# Nở hậu, tương đối vuông vức
# Nở hậu, hình đa giác, nhiều góc cạnh
# Hình dáng bị che khuất
# Vuông vức, chỉ có đường vào đất, đất bị che khuất
# Tương đối vuông vức (nở hậu 7,77m)
# Tương đối vuông vức, hình chữ nhật dài
# Nở hậu chữ L
# Khá Vuông vức
# Tứ giác
# Tương đồi vuông vức
# Tứ giác, tương đối vuông vức
# Đất hình dáng đa giác lồi lõm phức tạp
# Phần lớn bị che khuất
# Đa giác tóp hậu
# Vuông vức (nở hậu)
# Vuông vức, đất có chiều dài sâu
# Hình ngũ giác, vuông vức
# Đa giác, tương đối vuông vức
# Hình chữ nhật, vuông vức
# Hình chữ nhật, tương đối vuông vức
# Hình đa giác, nhiều góc cạnh
# Lô góc, tương đối vuông vức
# Phần lớn đất nằm ở phía sau
# Hình đa giác, không vuông vức, một phần đất bị che khuất
# Phần lớn mặt tiền bị che khuất
# Chữ T, nở hậu
# Kém vuông vức, bị khuyết
# tương đối Vuông vức
# 1 phần bị che khuất
# Đa giác, lòi lõm
# Đa giác, phần đất phía trong tương đối vuông
# Đất đa giác, tóp hậu
# Hình tứ giác
# Hình đa giác nhiều góc cạnh, tóp hậu
# Hình đa giác
# Đất hình chữ nhật có chiều dài tương đối sâu
# Hình dáng tương đối
# Hình thang
# Cân đối
# nở hậu
# Đa giác chữ T
# Tương đới vuông vức
# Nhà 1 trệt, 1 lầu
# Phần lớn đất bị che khuất phía sau
# Tương đối vuông vức, một phần đất bị che khuất
# Đa Giác
# Tương đối vuông vức, phần đuôi tài sản có hình vạt chéo
# Tương đối vuông vức, phần mặt tiền đất có 1 phần bị che khuất
# Hình chữ nhật dài không vuông vức
# Hình chữ nhật dài, mặt tiền tương đối hẹp
# Hình đa giác, tương đối vuông
# Đa giác, không vuông vức, đất bị che khuất
# Đa giác, không vuông vức, phần lớn đất bị che khuất
# Vuông vức, chỉ có đường vào đất, đất không giáp đường
# Tuong đối vuông vức
# Hình tam giác tóp hậu
# Hình đa giác không cân đối
# Nở hậu 12,3m
# Hình Tam Giác
# Vuông, nở hậu
# Hình chữ L, mặt tiền bị che khuất
# Tương đối vuông, đất bị che khuất toàn bộ
# Không vuông vức, phần lớn đất bị che khuất, phần đất phía trước hẹp và nợ rộng ở sau
# Không vuông vức, đa giác
# chữ nhật dài
# Nở hậu 42m
# Phần lớn thửa đất bị khuất lấp
# Chưa vuông vức
# Không vuông vức (tóp hậu 42m)
# Đất vuông vức, có chiều dài sâu
# Đất vuông vức
# Đa giác lồi lõm
# Hình tam giác, không vuông vức
# Hình đa giác, không vuông vức, bị eo hẹp giữa đất
# Tương đối vuông vức, đất bị che khuất
# Nở hậu 31m
# Tương đối vuông vức, mặt tiền kp là 1 cạnh của hình tứ giác
# Tương đối vuông vức, hình chữ nhật vuông vức
# Chữ L, phần diện tích phía sau bị che khuất
# Tương đối, hơi tóp hậu
# Gần vuông vức
# Cơ bản
# 1
# Vuông vức, nở hậu #6,6m
# Vuông vức, nở hậu 10m
# Đa giác nhiều cạnh, thửa đất bị khuyết lỗ bên trong
# Đa giác nhiều cạnh, có ao lớn trên đất
# Tóp hậu (5,9m)
# Hình đa giác, khoảng 3/4 đất bị che khuất
# Hình chữ L, khoảng 1/2 đất bị che khuất
# Không vuông vức (Hình chữ L, tóp hậu phía sau)
# Hình chữ L (Tóp hậu phía sau)
# Đa giác nhiều góc cạnh 1/2 đất bị che khuất
# Nở hậu (chữ L)
# Nở hậu 23,3m
# Nở hậu 16,5m
# Nở hậu 24m
# Hình đa giác tương đối vuông, phần lớn đất bị che khuất
# Hình bình hành
# Đa giác tương đối vuông
# Đa giác không vuông hơn 10 cạnh, nở hậu
# Hình chữ nhật, mặt sau tóp hậu
# Đa giác, phần lớn diện tích đất bị che khuất
# Nhiều góc cạnh, không vuông vức
# Hình đa giác nhiều góc cạnh, không cân đối
# Đa giác, nhiều góc cạnh, đoạn eo hẹp nhất rộng khoảng 5m
# Không vuông vức, đất có chiều dài sâu
# Tương đối vuông vức, nở hậu 12,97m
# Khá vuông vắn, nở hậu
# Tương đối vuông vức (xéo hậu)
# Không vuông vức (hình chữ L)
# Thóp hậu
# Nở hậu 50m
# Chữ L, phần lớn diện tích đất phía sau bị che khuất
# chữ T đa giác
# Tương đối vuông, nở hậu
# Đất lệch do không nằm thẳng hàng với mặt tiền đường
# Tương đối vuông vức, phần lớn đất bị che khuất, đường đi thẳng vào đất
# Nhà 1 trệt, 2 lầu
# Đa giác 1 phần đất bị che khuất
# Phần lớn đất nn bị che khuất phía sau
# Hình tứ giác tương đối vuông vức
# tương đối
# Chữ nhật
# Hình chứ L, không cân đối
# Hình nón
# Không Vuông Vức
# Đa giác không đều, hình dáng phức tạp, có kênh cắt ngang đất, có khuyết lỗ trong thửa đất, mặt tiền không liền nhau
# Đa giác không đều, hình dáng phức tạp
# Hình chữ L, có một phần nhỏ đất bị che khuất
# Hình đa giác, phần lớn đất bị che khuất phía sau
# Hình đa giác, phía sau có ao nước
# Đất trống
# Hình đa giác, mặt tiền nhỏ che khuất diện tích đất đằng sau
# Tam giác, tóp hậu
# Đa giác không vuông vức
# Không Vuông vắn
# Tương đối vuông vức, mặt tiền thửa đất thụt vào so với đường giao thông khoảng 6m
# Hình đa giác, khoảng 80% diện tích bị che khuất
# Không vuông vức, mặt tiền bị hẹp, tóp hậu
# Hình đa giác, mặt tiền bị che khuất
# Không vuông
# Hình đa giác nhiều góc cạnh, hầu hết thửa đất bị che khuất phía sau
# Tương đối vuông vức, hẹp về phía mặt hậu
# Đa giác nhiều góc cạnh, lồi lõm
# Đa giác, phía sau tóp hậu nhiều
# Hình đa giác, mặt tiền hẹp
# Hình đa giác nhiều góc canh
# Hình đa giác, mặt tiền hẹp, phần lớn đất che khuất
# Hình đa giác, 90% diện tích đất bị che khuất phía sau
# Hình đa giác nhiều góc cạnh, không vuông
# Hình đa giác nhiều góc cạnh, kém vuông
# Vuông vức, nở hậu #7,18
# Hình mũi tên
# Tương đối vuống vức
# Tương đối vương vức
# Tương đối
# tóp hậu
# Không vuong vức
# San lấp 50%, có ao phía sau
# Tương đối, vuông vức, tóp hậu
# Đa giác phần lớn bị che khuất
# Đa giác, tóp hậu
# Hình tam giác, tóp hậu
# Tương đối vuông, trên đất có ao

# %%
for i in (df["other"].unique()):
    print(i)
# Out:
# Không có
# nan
# None
# 0
# Bình thường
# QH SDĐ: ODT
# QH XD: HNK
# QH SDĐ: ODT, CLN
# QH XD: Đất nhà ở liên kế xây dựng mới
# QH SDĐ: CLN
# QH XD: Đất công trình công cộng
# Cách chùa khoảng 40m
# Bãi Dài Cam Ranh, khu vực chưa có dân cư sinh sống và vắng các dự án du lịch, xung quanh chủ yếu là đất trống
# Trung tâm thành phố Nha Trang, dân cư và du lịch sầm uất, kinh tế phát triển
# Thời hạn sử dụng đến ngày 06/9/2054
# Mặt tiền thụt, có khả năng gần khu mộ
# Không
# Đất có đường điện bắt ngang
# 0.0
# Gần cở sở tôn giáo
# Ngay vòng xoay thuận tiện cho việc kinh doanh, mua bán sầm uất
# Đất tương đối bằng phẳng, quy hoạch thổ cư
# Khu vực cách nghĩa trang 100m
# Đất chưa san nền
# Đất đã san nền
# QH đất TMDV Cổng trước Sân bay Long Thành
# Quy hoạch CLN
# Quy hoạch thổ cư
# Không
# Đối diện nghĩa trang
# Gần nghĩa trang
# Đất trống
# Cách nghĩa trang khoảng 10m, quy hoạch đất hỗn hợp, hẻm cụt
# Phần lớn đã san lấp bằng phẳng
# Chưa san lấp, mục đích để trồng cây
# Tương đối vuông vức
# Gần trung tâm, đầy đủ đa dạng tiện ích
# Kém hơn TSTĐ
# Trên thửa đất có các đường bê tông rộng khoảng 4m
# QH đất TMDV, bị QH DGT cắt ngang
# QH đất ở
# QH đất CLN
# Tương đồng
# Kém lợi thế hơn
# Vuông vức
# Tương đối vuông vức,  phần lớn đất bị che khuất
# View biển
# View nội khu
# Gần mộ
# Nhà hoàn thiện mặt ngoài, thô mặt trong
# Giáp sông
# Giáp kênh
# Đối diện Đài Tổ quốc ghi công
# Hẻm đâm
# Kinh doanh thuận tiện
# Quy hoạch đất ở
# Quy hoạch đất Hỗn hợp
# Đất ở xây dựng mới
# Khoảng 3/4 thửa đất nằm trong ranh QH
# Thửa đất nằm trong ranh QH
# Một phần thửa đất nằm trong ranh QH
# QH đất LUC
# Quy hoạch đất LUC, nằm kế chùa
# Quy hoạch đất ONT
# Khu vực kinh doanh sầm uất
# Địa hình không bằng phẳng
# Thanh khoản kém
# Đường đâm
# Đất chưa san lấp
# Đất đã san lấp bằng phẳng
# Gần nghĩa trang, thiền viện
# Đất giáp sông, thuận lợi giao thông đường thủy
# Không giáp sông
# Đất đã được đổ cát san lấp mặt bằng, betong hóa
# Đất chưa san lấp mặt bằng
# Đất đã được đổ cát san lấp mặt bằng
# Đất đã san lấp mặt bằng
# Công viên, hồ bơi và gần trường học
# Cách công viên khoảng 200m
# Cách xa công viên và trường học kém lợi thế hơn TSTĐ
# Kinh doanh tương đối thuận lợi
# Kém thuận lợi honq
# 70%ONT
# 40%ONT
# Thị trấn Cây Dương
# Xã Tân Phước Hưng
# Kinh doanh thuận lợi
# Kinh doanh kém thuận lợi
# Trong phạm vi bán kính dưới 50m, tài sản tiếp giáp gần với mồ mả
# Kinh doanh bãi đậu xe
# Có một phần đất thuộc lộ giới đang được chủ sử dụng đất sử dụng
# Phía trước là khu vực mồ mả
# Khu dân cư ổn định, không mồ mả
# Penhouse
# Căn hộ
# Phần đất phía trước bằng phẳng, ngang bằng với mặt đường, phần đất phía sau làm rạch tưới tiêu cho cây
# Đất trũng, thấp hơn mặt đường
# Đã san lấp mặt bằng toàn bộ thửa đất
# Gần chợ, kinh doanh tốt
# Kinh doanh sầm uất
# Khá thưa thớt
# Đối diện ĐH Kiến trúc
# Có khoảng 70m² diện tích không được công nhận nhưng vẫn đang sử dụng
# có 44,1m2 đang sử dụng nhưng không được công nhận
# Tặng kèm 92,5m2 không được công nhận trên sổ
# Gần Giáo xứ
# Trong phạm vi bán kính dưới 20m, tài sản tiếp giáp với mồ mả nằm trong đất của người khác
# Kế chợ và trường học, thuận tiện mua bán sầm uất
# Nhà có lối đi chung
# Hẻm đường công cộng
# Khu nhà ở cao cấp 491 Nơ Trang Long, có công viên nội khu
# Kinh doanh dầu khí
# Bãi dài Cam Ranh, khu vực có nhiều dự án du lịch nghỉ dưỡng
# Đường đâm (nhẹ)
# 2 mặt tiền+1 mặt hẻm
# 1mt
# Đất hỗn hợp (QH nhóm 2)
# Hiện đang kinh doanh Resort
# Hiện để trống
# Hiện để ở
# QH: Đất nhóm nhà ở xây dựng mới
# KDC
# QH đất ở
# Sau đất là Nghĩa trang ngã ba Dòng Lăng
# Hình lục giác
# Lô góc
# Quy hoạch đất ở mật độ thấp
# Gần Suối Tiên, tuyến metro số 1 và cách Xa Lộ Hà Nội khoảng 600m
# Gần Đình Đông Sơn
# Hơn 50% diện tích đất thuộc quy hoạch mở đường
# Hình chữ L
# Tương đối vuông
# Đa giác
# chữ L
# Phần diện tích không được công nhận đang được sử dụng để kinh doanh khoảng 40m2
# Phần diện tích không được công nhận đang được sử dụng để kinh doanh khoảng 24m2
# Tương đồng TSTĐ
# Gần sân bay Tân Sơn Nhất
# Lợi thế kinh doanh tốt, đa dạng từ công trình hiện hữu
# Lợi thế kinh doanh tương đối từ công trình hiện hữu
# Đâm hẻm
# Đất trống, đang là ao trũng
# Đất trống, ngang bằng với mặt đường, bằng phẳng
# Đất đã san lấp
# Bán kính 50m có vài ngôi mộ
# Trước đất có trụ điện
# Quy hoạch mở rộng đường nhựa 10m
# Hai mặt tiền hẻm
# Phần đất phía sau bị che khuất 17,21m
# Mặt tiền sông
# Quy hoạch đất nông nghiệp
# Quy hoạch đất ở
# Quy hoạch đất nông nghiệp kết hợp đất ở
# Cách cơ sở tôn giáo trong bán kính khoảng 60m
# Đất đã san lấp ngang mặt đường
# Đất chưa san lấp, thế trũng, hiện đang trồng lúa
# Đất chưa san lấp, thế cao hơn đất lúa
# Đất TMD lâu dài: 224m2
# Đất TMD 6/9/2073: 758,5m2
# Đất LUC 01/07/2064 - 04/06/2067
# Đất LUC 06/09/2067
# Đất CLN 15/10/2043
# Đất LUC 01/07/2064
# Cách mộ khoảng 80m
# Trong bán kính 40m có nhiều khu mộ
# Gần chùa
# Cách công trình tôn giáo khoảng 50m
# Cách cơ sở tôn giáo trong bán kính 30m
# Cách cơ sở tôn giáo trong bán kính 70m
# Đường đất
# Đường đá
# Đường nhựa
# Phía sau giáp đường sắt Bắc Nam, có tiếng ồn và nguy hiểm về mặt giao thông
# Có suối chảy ngang đất, suối tắm được, phù hợp nghỉ mát + tưới tiêu
# Một phần đất đang trồng lúa, thấp hơn mặt đường
# Đất được san lấp
# Cách 200m có khu nghĩa địa tự phát
# Cách 400m có khu nghĩa địa tự phát
# Thời hạn sử dụng đến ngày 31/12/2057
# Đối diện công trình tâm linh (Miếu)
# Để ở
# Có hoạt động kinh doanh buôn bán
# Cách chợ 700m
# Cách chợ 63m
# Cách chợ 60m
# Cách chợ 500m
# -
# Kinh doanh cây xăng
# Gần Phố đi bộ, cv ven sông
# QH đất TMDV, đất đồi, view biển
# QH đất TMDV
# Đất có quy hoạch sử dụng đất là đất TMD
# Đất có quy hoạch sử dụng đất là đất CLN
# Đất có quy hoạch sử dụng đất 90% là đất CLN, 10% là đất ONT
# Đất có quy hoạch sử dụng đất là đất BHK
# TMD
# CLN
# Tài sản cách chùa khoảng 80m
# Cách chợ Chu Hải khoảng 200m
# Cách nhà thờ khoảng 500m
# Cách tịnh xá khoảng 150m, xung quanh trong phạm vi 300m, có nhiều công trình tâm linh
# Tài sản cách chùa khoảng 100m
# Tài sản cách chùa khoảng 200m
# Tài sản cách nhà thờ khoảng 500m
# Tài sản cách tịnh xá khoảng 150m, xung quanh trong phạm vi 300m, có nhiều công trình tâm linh
# Tài sản cách chùa khoảng 500m
# San lấp mặt bằng, bebe tông hóa
# Có quy hoạch đường giao thông cắt ngang mảnh đất
# % đất ở thấp
# % đất ở cao
# Quy hoạch đất LUC
# Khu vực cách nghĩa trang 10m
# Có 762,1m² đất nuôi trồng thủy sản
# Gần bệnh viện đa khoa xuyên á
# Kê bên nghĩa trang tập trung
# Phía sau có mương nước
# Đất trồng cây lâu năm 01/07/2064
# Đất trồng CLN sử dụng đến ngày 03/10/2045
# Đất trồng CLN sử dụng đến hết ngày 01/07/2064
# Đất trồng cây lâu năm sử dụng hết ngày 16/08/2062
# Đất trồng lúa nước sử dụng đến ngày 06/06/2064
# đường điện cao áp đi ngang qua đất - Cách cột điện cao thế khoảng 36m
# Đường điện cao áp đi ngang qua đất - TSĐG đối diện trụ điện cao thế
# Cách chùa khoảng 90m , Cách sông Vàm Cỏ Tây 150m
# Gần UBND Bình Tâm
# Cách Tu viện tịnh tâm khoảng 140m
# Đất nền dự án
# Bàn giao thô, nhà trống
# Tiếp giáp Trạm 100kw (có khả năng), tiếp giáp sông Hậu
# Tiếp giáp mương nước
# Gần khu hành chính, dân cư, trường học
# không có
# Hiện có trồng thanh long, 3 căn nhà yến và 1 nhà biệt thự, đối diện hồ Cà Giang, có hành lang đường điện đi ngang thửa đất số 247
# Hẻm đâm, đối diện là khu mộ đã được rào bằng tường (nửa phía trên là tôn)
# Cách nghĩa trang liệt sĩ thị trấn Lương Sơn khoảng 240m
# Quy hoạch đất TMDV
# Quy hoạch đất ODT
# Cách khu nghĩa trang khoảng 30m
# Có mộ trên đất
# Nội thất đầy đủ
# Nội thất cơ bản chủ đầu tư
# Cách chùa Huệ Quang khoảng 500m
# Cách khu vực trường học khoảng 20m
# Có 21,76m² đất đang sử dụng nhưng chưa được công nhận trong GCN QSDĐ
# Có 0,31m² đất đang sử dụng nhưng chưa được công nhận trong GCN QSDĐ
# Khu vực có mộ cách 40m
# Nhà trống
# Nhà đã hoàn thiện nội thất
# Chỉ được chuyển nhượng sau khi xây dựng CTXD theo quy định
# Được chuyển nhượng tự do
# Đã hoàn thiện mặt ngoài và trong, nội thất đầy đủ
# Sát khu mộ
# Phía sau giáp suối Dung
# Hẻm đâm, đối diện là khu mộ
# Kế bên đất nghĩa trang
# Đất thấp hơn mặt đường
# Đất chưa được san lấp, cỏ cây mọc dại nhiều
# Đã san lấp cỏ dại
# Trong bán kính 60m có cơ sở tôn giáo (Đình làng)
# Một phần đất chưa được phát hoang có 1 ao nhỏ trong đất
# Đất đã được phát hoang
# Đất trống đã được phát hoang
# Đất chưa được phát hoang có 1 ao nhỏ trong đất
# Trên đất không có mộ
# Thuộc quy hoạch đất đô thị du lịch hỗn hợp
# Khoảng 75% diện tích đất thuộc quy hoạch đất cây xanh
# Thuộc quy hoạch đất ở
# Toàn bộ diện tích đất thuộc quy hoạch đất cây xanh
# Có kênh rạch kế bên
# Có kênh rạch kế bên, cột điện trên đất
# Diện tích thực tế sử dụng khoảng 310m²
# Chung cư 5 tầng, không có thang máy
# Chung cư 30 tầng, có thang máy
# Đất bị thấp hơn đường khoảng 20cm
# Ngang bằng với đường
# Nội khu
# Hồ
# Nội khu
# Cách nghĩa trang Giáo xứ Bắc Thần khoảng 180m
# Tổ hợp liền kề, biệt thự
# Tổ hợp thương mại dịch vụ, căn hộ, khách sạn 5*
# Tổ hợp shophouse, biệt thự
# Tổ hợp liền kề, biệt thự. View hồ, hoặc khu TMDV
# Tổ hợp liền kề, biệt thự + view suối hoặc TMDV
# Tổ hợp liền kề, biệt thự, view suối hoặc TMDV
# View hồ
# 2 khe thoáng
# Đối diện nhà văn hóa, đất xã hội (đất trống)
# Có NVH, đất xã hội
# 2 khe thoáng/đối diện nhà văn hóa
# Đối diện nhà văn hóa, đất xã hội
# Gần đường chính
# View hồ trực diện
# Khu dân cư đông đúc
# Gần nghĩa trang Gò Dưa
# Dân cư thưa thớt
# Gần KDC
# Khu vực tài sản có nhiều mồ mả
# Cách nghĩa trang 150m
# Đất trống, đất thấp hơn mặt đường khoảng 0,5m và trũng dần về sau
# Trên đất có nhà gỗ, đất ngang bằng với mặt đường, bằng phẳng
# Đất trống, có tường rào gạch bao quanh, đất ngang bằng với mặt đường, bằng phẳng
#  Ngay đoạn cua ngã 3 đâm thẳng vào nhà
# Mặt tiền hẻm bình thường
# 23
# Ngay ngã ba đoạn cua đâm thẳng vào nhà
# Mặt tiền đường bình thường
# Dân cư đông đúc
# 42
# Dân cư tương đối, đối diện nghĩa trang
# Dân cư tương đối
# Gần Đình Thần
# Giá chưa gồm chi phí ra sổ
# Giá chưa chiết khấu
# Đối diện UBND tỉnh và các sở ban ngành, an ninh tốt
# Cách UBND tỉnh khoảng 1,7km, an ninh bảo đảm
# Cách UBND tỉnh khoảng 1,5km, an ninh bảo đảm
# Cách UBND tỉnh khoảng 6km, an ninh tương đối
# Phần lớn đất là ao nước trũng
# Đất bằng phẳng
# Một phần đất là ao nước trũng
# Đất thấp hơn mặt đường khoảng 0,5m
# Đất thấp hơn mặt đường khoảng 1m
# Một phần đất ngang với mặt đường, 1 phần đất thấp hơn mặt đường khoảng 1m
# Đất đang là ao sen, thấp hơn mặt đường khoảng 1m
# Đất ngang bằng với mặt đường
# Một phần đất đã được san lấp, ngang bằng với mặt đường, phần lớn đất thấp hơn mặt đường khoảng 0,5m
# Đất chưa được san lấp, thấp hơn mặt đường khoảng 0,5m
# Đất ngang bằng so với mặt đường
# Một phần đất đã được san lấp, đổ bê tông, cao hơn so với mặt đường, một phần đất thấp hơn mặt đường khoảng 0,5m
# Đất ngang bằng với mặt đường, kinh doanh bãi giữ xe
# Đất đã được san lấp
# Đất chưa được san lấp
# Đất chưa được san lấp, hiện đang là eo sen trũng
# Đất ngang với mặt đường
# San lấp mặt bằng
# Chưa san lấp mặt bằng
# Phần đất thuộc lộ giới có 2 phần mộ to, 3 phần mộ nhỏ
# Trên đất có mộ
# Khu vực kinh doanh tương đối
# Khu vực kinh doanh sầm uất, đa dang nhiều ngành nghề
# Khu vực kinh doanh tốt
# Hạn chế hành lang đường điện
# Chưa biết
# Dân cư đông đúc, trước nhà có tụ điện và cây xanh lớn
# Dân cư tập trung đông đúc hơn
# Dân cư tương đồng TSTĐ
# Dân cư ổn định, đông đúc
# Nằm ở cuối đường, dân cư thưa thớt hơn
# Đất có trồng khoai mì, bằng phẳng, thấp hơn mặt đường khoảng 1m
# Đất bằng phẳng ngang với mặt đường
# Đất có cây cỏ mọc rậm rạp, chưa được ban bằng phẳng, thấp hơn mặt đường khoảng 1m - 1,5m.
# Cách Bảo Đàn Liên Trì 2 căn nhà
# Gần chợ, kinh doamnh tốt
# 1240
# Xung quanh có nhiều nghĩa trang
# Kế bên kho xăng
# Đường đi thẳng vào giữa thửa đất
# View công viên
# Mặt tiền đường Hoàng Thế Thiện
# TSTĐ cách nghĩa trang khoảng 150m
# Trên đất không có mộ, thửa bên cạnh có nhiều mộ gia đình
# Trên đất có 2 phần mộ
# Phía sau giáp Rạch Đình
# Đối diện công viên cây xanh
# KDC hiện hữu
# KDC đang hình thành
# Dân cư đông đúc, gần đường lớn
# Hẻm thông, vị trí ngay góc cua, bị che khuất bởi nhà kế bên
# Hẻm thông
# Hẻm cụt
# Phía sau và bên hông giáp kênh thủy lợi
# Phía sau giáp kinh thủy lợi
# Tài sản đang kinh doanh cây xăng
# 17/08/2056
# 11/03/2051
# Tiện ích đầy đủ, cơ sở hạ tầng đồng bộ
# Hẻm cụt, khu dân cư, Thới An 03 là đường thông giữa Lê Văn Khương và Lê Thị Riêng
# Hẻm thông, Thới An 09 (Võ Thị Phải là đường thông giữa Lê Văn Khương và Lê Thị Riêng
# Hẻm thông, Thới An 11 là đường thông giữa Lê Văn Khương và Trần Thị Cờ
# Gần KCN Tân Phú Thạnh
# Cách trường THCS Đông Phước A khoảng 240m, cách UBND xã Đông Phước A 140m
# cách UBND xã Đông Phước A 300m
# Gần nghĩa trang (khoảng 100m)
# Đoạn đường 2 chiều
# Đoạn đường 1 chiều
# Đất thấp hơn mặt đường, được san lấp 1 phần, cỏ dại mọc um tùm
# Trên đất có trồng cây cao su
# Đất gập ghềnh, thấp hơn mặt đường
# QH đất NN
# Đất thấp hơn mặt đường khoảng 2-3m
# Đất bằng mặt đường
# Trên đất trồng mít
# Trên đất trồng cây ăn trái
# Hẻm cụt, thửa đất thuộc quy hoạch đường giao thông hết 2/3 diện tích (tham khảo Guland)
# Quy hoạch đất ở tại nông thôn
# Quy hoạch đất trồng cây lâu năm
# Trên đất nghi ngờ có mộ
# 1 mặt tiền
# 2 mặt tiền
# Đâm đường
# Đối diện kênh
# Xa trung tâm hành chính xã Đông Thắng
# Gần trung tâm hành chính xã Đông Thắng
# Không có
# Khu vực tập trung KCN lớn
# Đang kinh doanh xăng dầu
# Nằm vị trí ngã 3
# Cách chùa khoảng 10m
# Cách chùa khoảng 20m
# Tiếp giáp mương lộ
# Tiếp giáp mặt tiền đường
# 2 mặt tiền, hẻm cụt
# Quy hoạch phần đất ở chiếm diện tích lớn
# Quy hoạch không có đất ở
# Phía sau giáp mương nước chưa được san lấp
# Mức độ kinh doanh
# Kém hơn
# tương đồng
# View sông
# Gần KCN Bình Minh
# Xa KCN Bình Minh
# Hiện đang trồng lúa, chưa san lấp
# Tài sản tiếp giáp đất quy hoạch NTD, hiện trạng đang là Nhà Thờ Tham Tướng B
# Xây dựng TTTM huyện Châu Thành
# Có ao rộng khoảng 4000m² trên đất
# Tài sản cuối hẻm
# Hẻm thông ra XXT
# Hiện trạng phần lớn là ao cá
# Gần chùa, trong phạm vi bán kính <30m của thửa đất có tiếp giáp mồ mả nằm trên phần đất của người khác
# Gần trường học, trung tâm xã Long Hòa
# Đất nằm trong hành lang an toàn lưới điện 110KV
# Nền đất thấp hơn mặt đường rất nhiều.
# Kinh doanh tương đối
# Ngay khu trung tâm, gần chợ, gần trường
# Gần Cụm công nghiệp Quốc Quang Long An
# Trên đất có ao chưa san lắp
# Gần nhà máy chế biến cao su, sông ô nhiễm
# Đối diện đất thổ mộ
# Gần Nghĩa trang Giáo xứ Nghĩa Yên
# Đất thấp hơn mặt đường, không bằng phẳng (giả định)
# Đất bằng phẳng với mặt đường
# Đất không bằng phẳng
# Ruộng lúa, thấp hơn mặt đường
# Đất ngang mặt đường, bằng phẳng
# Đất thấp hơn mặt đường, bằng phẳng
# 40% là đất, 60% là hồ nhân tạo
# Đất đang là ruộng trồng lúa, thấp trũng
# Quy hoạch đất sản xuất phi nông nghiệp
# Xây dựng showroom, office-tel
# Đã có GPXD công trình khách sạn, lối đi thẳng xuống bãi biển
# Cách 100m có nghĩa trang
# Cách 130m có nghĩa trang
# Cách 180m có nghĩa trang
# Cách 20m có công trình tôn giáo (chùa), cách 100m có nghĩa trang
# Hẻm sâu
# Khu TDC-DC Cụm CN Tân Phú Thạnh
# Cách Điện Biên Phủ khoảng 30m
# Chi phí bán hàng, chi phí tách thửa, lợi nhuận nhà đầu tư,…
# Dân cư bình thường
# Quy hoạch đất lúa
# Kế chợ
# Có mộ
# Hẻm hướng thẳng thửa đất.
# Đất đang trồng lúa nước, xung quanh là ruộng lúa
# Đất được san lấp, rào xung quanh
# Đường thông
# Hiện đang là ao
# Đã san lấp mặt bằng
# Hiện trồng lúa
# Sau trường học
# Phía cuối thửa đất có mộ gia
# Gần Nghĩa trang Phúc An Viên
# Đối diện xéo nghĩa trang
# Kinh doanh sầm uất, gần vòng xoay Phú Lâm
# Trên đất đang trồng cây tràm đã lớn
# Dân cư đông đúc, cách khu nghĩa trang khoảng 30m
# Địa hình đất đồi
# Địa hình bằng phẳng
# QH DGT
# đất cây cối mọc dại chưa san lấp
# trên đất trồng chuối và cây ăn quả có mương nước
# trên đất trồng chuối và rau không bằng phẳng
# trên đất có nhiêu cây cỏ có mương nước
# Đất bằng phẳng trên đất có nhà cấp 4
# trên đất có nhiêu cây cỏ mọc dại chưa san lấp
# Trên đất trồng cam, hạnh
# Đất lúa
# Đất lúa + thổ cư
# 1
# Đất ở hiện hữu cải tạo chỉnh trang
# ODT
# Đất dân cư hiện hữu cải tạo
# Đất biệt thự xây dựng mới khu đô thị Nam xa lộ Hà Nội (năm 2007)/ Đất cây xanh cảnh quan - công viên + Đất giao thông + Đất nhóm nhà ở hiện trạng (2013)
# Chưa san lấp
# Đất trũng làm ao tôm
# Giáp sông ông Đốc
# Khu vực buôn bán thuận lợi
# Giáp kênh Xáng Cùng
# Đất bằng phẳng, còn cây trên đất
# Dân cư thưa thớt, xung quanh chưa có nhiều người ở
# Quy hoạch DKV
# Đất trồng mì
# Đất trồng cao su
# Quy hoạch toàn bộ là đất giao thông
# Cách nhà thờ khoảng 40m
# Miếu bà Ngũ Hành
# Cách 500m có nhà thờ, cách 70m có nghĩa địa tự phát, bên hông phần mặt tiền và phía cuối đất giáp mộ
# Cách 500m có nhà thờ, cách 70m có nghĩa địa tự phát
# Cách 500m có nhà thờ, cách 70m có nghĩa địa tự phát, có mộ ở cuối đất
# Cách 80m có cơ sở tôn giáo, cách 40m có nghĩa địa tự phát
# Trên đất có 1 ngôi mộ gia đình
# Quy hoạch đất DKV
# Cách chùa Vàm Ray khoảng 100m
# Cách cơ sở tín ngưỡng tự phát khoảng 60m
# Cách nghĩa trang Thuận Bài khoảng 300m, quy hoạch dân cư dự kiến
# Toàn bộ đất thuộc QH đường tránh QL22
# QH đất ở + nông nghiệp
# QH đất nông nghiệp
# Hiện đang là cơ sở tôn giáo (Hội Thánh Báp Tít Thạnh Xuân)
# Quy hoạch đất nhóm nhà ở dự kiến xây dựng mới
# Đất nhóm nhà ở hiện hữu ổn định, cải tạo, chỉnh trang
# QH đất ở, lô góc
# Bên hông giáp Rạch, phần lớn diện tích đất chưa san lấp, bị trũng so với mặt tiền đường
# Bình thường, đã san lấp
# Cách nghĩa trang khoảng 80m
# Đất dốc hướng lên so với mặt đường
# Gần nghĩa địa Phú Ngọc
# Trên đất trồng xoài
# Quy hoạch đất CLN
# Địa hình nhấp nhô, địa hình chênh lệch với mặt đường trong khoảng 1-3m
# Địa hình thoải dần về sau, địa hình chênh lệch với mặt đường trong khoảng 1-3m
# Địa hình tương đối bằng phẳng
# Địa hình thoải dần về sau, địa hình chênh lệch với mặt đường trong khoảng 1m
# Chưa san lấp, phát quang cỏ dại, tài sản bị đọng nước
# Chưa phát quang cỏ dại
# Đầy đủ
# Cách nghĩa trang khoảng 450m
# Cách nghĩa trang khoảng 290m
# Cách nghĩa trang khoảng 170m
# Quy hoạch nhà biệt thự (hạn chế mật độ xây dựng)
# Quy hoạch đất ở khu dân cư
# Mặt sau của đất dưới chân cầu Trần Văn Giàu, đất bị đường đâm
# Cách 30m có nghĩa trang
# 2058
# Dưới đường điện
# Mộ
# Đối diện trường
# Phía sau có hồ nước
# Gần vòng xoay, thuận tiện kinh doanh, đang KD bãi xe và sân cầu lông, sân bóng
# Nhà đang kinh doanh CHDV
# Kinh doanh Trung tâm Anh Ngữ
# Đất không bằng phẳng, trũng
# Đất đã được san lấp, bằng phẳng
# Đất không bằng phẳng, trũng, phần lớn đang là ao nước
# Đất chưa san nền, hiện trạng không bằng phẳng
# Nhà ở
# Khu nhà liền kề, có nhà ở cán bộ
# Khu nhà ở thường, đang kinh doanh CHDV
# Khu nhà ở thường
# Có nhà, ao cá và điện nước
# Đất trũng, chưa san lấp, thuộc quy hoạch hành lang an toàn lưới điện
# Đất trũng, chưa san lấp
# Đất đa phần nằm trong phần hành lang bảo vệ an toàn đường điện (hạn chế xây dựng nhà cao tầng)
# Có trụ điện 550KV trên đất, đất đa phần nằm trong phần hành lang bảo vệ an toàn đường điện
# Gần Nhà máy Gạch Hoffman Phước Thạnh
# Khoảng 5000m2 chưa san lấp
# Đã san lấp, cách tài sản khoảng 20m có miếu nhỏ
# Đã san lấp
# Đã san lấp, gần khu công nghiệp Hòa Bình
# Sau lưng nghĩa trang liệt sỹ Đức Hòa
# Bán kính dưới 30m có nghĩa trang, chùa
# Gần Khu mua sắm chợ Resco
# Gần MT đường TL8
# 2mt
# không
# Cách mộ khoảng 30m
# Thuận lợi kinh doanh
# 0.7
# Đang kinh doan cửa hàng xăng dầu
# Có giấy phép cây xăng
# Đang kinh doanh cửa hàng xăng dầu và có 1.027m² thuộc HLLG được CSH sử dụng
# Có giấy phép kinh doanh cửa hàng xăng dầu và có 864m² thuộc HLLG được CSH sử dụng
# Nội thất cơ bản
# Nhà thô
# Đã san lấp, đất thấp hơn mặt tiền đường
# San lấp ngang mặt tiền đường
# Trên đất có mộ ( 2 khu mộ khoảng 3-4 mộ)
# Đất trống, đã được san lấp bằng phẳng, trên đất không có mộ
# Đối diện có đất cơ sở tín ngưỡng
# QH Khu sản xuất NN kết hợp dân cư nông thôn
# Phần lớn đất nông nghiệp bị che khuất phía sau (khoảng 90%)
# Phần lớn đất nông nghiệp bị che khuất phía sau (khoảng 90%), có 2 hồ nước trong phần đất nông nghiệp (rộng khoảng 570m² và 1700m²)
# Đất trồng lúa, trũng, chưa san lấp
# Quy hoạch ONT
# Đất trũng, trồng lúa
# Đã san lấp bằng phẳng
# Có vườn cao su 6 năm tuổi
# Cách nghĩa trang khoảng 400m
# Cách nghĩa trang khoảng 300m
# giáp bờ kênh, mua đất chủ bao xây cầu
# QH SKC
# QH  CLN
# Nằm trong hành lang lưới điện
# Bình thường, có 2 ao trên đất
# Trong phạm vi bán kính dưới 20m, thửa đất tiếp giáp với mồ mả
# Quy hoạch SKX
# Quy hoạch đất cây, đất ở
# Trong phạm vi dưới 30, thửa đất tiếp giáp mồ mả nằm trên đất của người khác
# Dân cư đông, có tiềm năng
# Tương đồng
# Khu vực nhiều mồ mả
# Trong bán kính 50m có nghĩa trang
# Trong phạm vị bán kính dưới 30m thửa đất tiếp giáp mồ mã nằm trên phần đất của người khác
# Gần chợ, lợi thế kinh doanh
# kinh doanh thưa thớt, xa khu dân cư
# View hồ suối môn
# khoảng 20% diện tích thuộc QH SKC, còn lại QH đất ở
# QH SKC ngoài KCN
# QH ONT hiện hữu chỉnh trang
# Có mộ tại thửa đất ngay kế bên
# Xung quanh khả năng có mộ
# Cách Trường tiểu học An Thới khoảng 50m
# Đã san lấp bằng mặt đường
# Hiện đang trồng lúa, đất trũng
# Kế bên tài sản tiếp giáp đất nghĩa trang
# Có mương nội bộ cắt ngang
# HD thuê 65tr/tháng
# HD thuê 120tr/tháng
# HD thuê 25tr/tháng
# Nằm bên hông nhà thờ
# Cách nghĩa trag khoảng 70m
# Có dãy tường che, chưa phá dỡ
# Đối diện là Đan Viện, bán kính 50m có mộ xung quanh
# Bán kính 50m có mộ xung quanh
# Phần lớn đất bị che khuất phía sau
# Trên đất chứa nhiều rác thải sinh hoạt chưa được phát dọn
# Gần Chợ Nàng Mau thuận tiện cho việc buôn bán phát triển
# Trong phạm vi khoảng 50m có đường dây hạ thế đi ngang
# Gần khu vực nhiều nghĩa trang
# Hiện đang nuôi tôm, đất vuông tôm
# Cách mã nhà họ Lương khoảng 290m
# Nằm ngay chân cầu
# Đất trồng điều, cao su
# Đất trồng điều
# Trong phạm vi dưới 30m, thửa đất tiếp giáp mồ mả nằm trên đất của người khác
# Có CT tâm linh
#  Tọa lạc dưới chân đồi
# Có trụ điện trước tài sản
# Trước khi tiếp giáp với đường, phải đi qua thửa đất 109
# Trụ điện
# Nằm tại khu vực xung quanh có nhiều mồ mả
# Đường cụt
# Đường đất tự đổ, trên sổ không có đường
# Gần khu nghĩa trang
# Có trụ điện trên đất và nằm trong hành lang an toàn đường dây 500KV Mỹ Tho - Đức Hòa
# QH: Đất dân cư dự kiến xây mới
# Có 03 mộ gia định trên đất
# Phía trước có mương nước rộng khoảng 1m
# Có kênh song song với đường
# Trên sổ không công công nhận đường
# QH Đất hỗn hợp
# Trong khu vực chợ, có thể kinh doanh buôn bán
# Trồng cây sầu riêng 4-5 năm tuổi
# Trồng cây sầu riêng 2 năm tuổi
# Trồng cây sầu riêng 4-5 tuổi đã thu hoạch năm đầu
# Gần chùa tại gia, trong phạm vi bán kính dưới 80m có dây điện cao thế đi ngang và khu mồ mã
# Quy hoạch đất LUA
# Trong bán kính khoảng 50m xung quanh có mộ của gia đình khác
# QH Đất ở xây dựng mới
# Cách biên giới Việt Nam - Campuchia khoảng
# QH ONT
# QH TMDV
# Đất vuông NTS
# Đất trồng rẫy, cây ăn trái
# Phía sau có 3 mộ gia đình
# Đất trũng, cạnh mộ gia đình
# Bên cạnh thửa đất có mộ gia đình
# Cách khu vực mộ khoảng 278m
# Cách khu vực mộ khoảng 230m
# Sau lưng là nghĩa trang
# Xã Mỹ Khánh
# Thị trấn Phong Điền
# View sông
# Kế bên BV Đa khoa Xuyên Á
# Khu hành chính
# Kế bên trường học
# Nhà cuối hẻm cụt
# Cách khu mộ khoảng 50m
# Trên đất có cái ao nước nhỏ khoảng 100m²
# Tiện ích hồ cảnh quan, khu thương mại, công viên, hồ bơi trong nhà
# Tiện ích hồ cảnh quan, khu thương mại, cây xanh, hồ bơi trong nhà
# Tiện ích khu thương mại, hồ bơi công cộng
# Tiện ích hồ cảnh quan, khu thương mại, spa, cây xanh, hồ bơi công cộng
# Đang kinh doanh cơ sở mai táng
# Đất thấp hơn mặt tiền đường
# Đất trũng
# Cây cối mọc cao, một phần đất ngang bằng với mặt đường, một phần đất trồng lúa thấp hơn mặt đường
# Đất trồng lúa, thấp hơn mặt đường
# Cách nghĩa trang khoảng 70m
# Giáp ranh đất có khu mộ
# QH Thổ cư
# QH Thổ cư + CLN
# Kèm nội thất
# Đang làm hạ tầng
# Hạ tầng hoàn chỉnh
# Đất đâm đường
# Đông dân cư
# Khu đô thị hạ tầng đầy đủ
# Đông dân cư, đối diện cây xăng
# Đối diện cây xăng
# Đối diện chùa Phước Long, cách nghĩa trang khoảng 180m
# Gần Nghĩa trang xã Hòa Phú
# Kế bên Đình Mỹ Đạo
# Cách nghĩa trang khoảng 180m
# Khu vực xung quanh gần ni viện, trạm biến áp
# Đất thấp hơn mặt tiền đường, quy hoạch ONT
# Tiếp giáp khu đất quy hoạch bãi rác, nằm dưới cao tốc, quy hoạch CLN
# Bán kính 80m có nghĩa trang
# Đối diện chợ Đo Đạc thường xuyên họp chợ, buôn bán tấp nập phía trước
# Khu vực ô nhiễm
# Đã lên liếp
# Toàn bộ diện tích thuộc Quy hoạch đất TMD
# Một phần diện tích thuộc Quy hoạch đất TSC, còn lại là đất ODT
# Đất thấp hơn mặt tiền đường khoảng 3m
# Trong phạm vi bán kính dưới 70m, tài sản tiếp giáp với nghĩa trang
# Có mộ ở thửa đất kế bên
# Trong phạm vi bán kính dưới 100m, tài sản tiếp giáp với nghĩa trang
# Gần TSTĐ có khu mộ nằm trên các thửa đất khác
# Trong phạm vi bán kính dưới 20m, tài sản tiếp giáp với đường điện
# sử dụng chung
# Gần nghĩa trang tập trung
# 1450
# Gần chùa, nghĩa địa
# ngõ cụt
# Cách nghĩa trang tập trung khoảng 600m
# Xung quanh có nhiều khu mộ
# Quy hoạch đất công trình công cộng ngoài đơn vị ở (TMDV)
# Đang làm CHDV, QH đất ở
# Quán cà phê, có thang máy
# Đang bán cơm
# Không gần mộ
# Trong phạm vi bán kính dưới 20m, tài sản tiếp giáp với nhiều mồ mả nằm trên phần đất của người khác
# Bị đường đâm
# Đối diện chợ Nàng 2
# Cách chợ Nàng 2 khoảng 750m, gần KCN
# Cách chợ Nàng 2 khoảng 1,6km
# Cách chợ Nàng 2 khoảng 1,3km
# Gần nghĩa địa
# Kinh doanh thuận lợi (gần vòng xoay Lê Đại Hành)
# gần mộ
# Cách nghĩa trang khoảng 100m
# Đã san lấp bằng phẳng một phần đất
# Chưa san lấp, hiện đang làm vườn
# 70%CLN, 30%ODT
# 100%ODT
# 100%CLN
# Cách nghĩa địa khoảng 750m
# Đối diện chùa Phật Đà
# Trong phạm vi bán kính 20m, tiếp giáp với nghĩa trang
# Đối diện có mộ
# Hình dáng thửa sau QH
# QH đất cây
# Cách nghĩa trang khoảng 140m
# Cách nghĩa trang khoảng 60m
# Cách nghĩa trang khoảng
# Trong phạm vi bán kính dưới 80m, thửa đất tiếp giáp mồ mã nằm trên phần đất của người khác
# Cách 350m có nghĩa trang
# Cách nghĩa trang khoảng 40m
# Cách chùa Hiếu Nghiêm khoảng 180m
# Có dây điện 22Kv đi sau đất
# Nằm ngay trạm thu phí
# Có dây điện 220Kv đi sau đất
# Lô thường, nhà đã hoàn thiện, nội thất đầy đủ
# Cách ranh giới nghĩa trang khoảng 36m
# San lấp 50%, có ao phía sau
# Bị 2 hẻm đâm, bán kính 70m có nghĩa trang
# Bình thường, bán kính 80m có nghĩa trang
# Đối diện chung cư Dreamhome 2, khu vực kinh doanh sầm uất
# Đất bằng phẳng, đã trải bê tông, hiện đang dùng kinh doanh cây xăng
# Trên đất có trồng cây sầu riêng, mít, ổi, nằm trong khu vực có lưới điện cao thế
# Đất trống bằng phẳng
# Đất bằng phẳng hiện đang xây nhà
# Đất cỏ cây mọc dại, chưa san lấp, trên đất có căn nhà tạm
# Trên đất đang trồng cây cao su, đất thấp hơn mặt đường
# Trên đất có nhà, hiện đang kinh doanh sửa xe
# Đất trống cỏ cây mọc dại nhiều chưa san lắp
# Đất trống có hàng rào bao quanh
# Trên đất có trồng cây huỳnh đàn
# đất bị lõm phía sau
# bằng phẳng
# Khu vực kinh doanh kém hơn TSTĐ
# Đất bằng phẳng, đã trải bê tông chỗ kinh doanh cây xăng, phía sau có nhà xưởng sấy cà phê
# Trên đất có cỏ cây mọc dại chưa san lấp
# Đất không bằng phẳng đang trồng mì
# Phía trước đang xây nhà
# đối diện trường học, trên đất hiện trồng mì
# Đất có cỏ cây mọc dại chưa san lấp
# Đất trống bằng phẳng, có hàng rào bao quanh
# Đất phía trước bằng phẳng trải bê tông hiện đang kinh doanh cây xăng, khoảng 1000m² sau đất thấp hơn mặt đường khoảng 5m hiện đang kinh doanh nhà hàng
# Gần đường điện, Kênh đối diện bị ô nhiễm
# Đất trồng cà phê
# Đất bằng phẳng, trên đất có cây cối mọc dại
# Đất thấp hơn đường, trên đất có cây cối mọc dại
# Đang trồng cà phê
# Trong phạm ví bán kính dưới 30m thửa đất tiếp giáp với Chùa Phổ Quang
# Trong phạm ví bán kính dưới 20m thửa đất tiếp giáp với Nhà thờ tin lành An Phú Đông
# Cách nghĩa trang khoảng 700m
# Đất cỏ cây mọc nhiều chưa san lấp
# Đất thấp hơn đường khoảng 1m
# Phần đầu đã san đất bằng đường, phần sau đất thấp hơn đường
# Kinh doanh cây xăng, sau lưng giáp nghĩa trang có mồ mã
# Kinh doanh sửa xe
# View nội khu thành phố
# View sông Hàn
# Đất thấp hơn đường nữa mét
# Trong phạm vi bán kính dưới 20m tiếp giáp với Tịnh thất Hương Thiền
# Có 1 phần đất khoảng 111,4m² đang được sử dụng không công nhận trong GCN
# Có 1 phần đất khoảng 48,3m² đang được sử dụng không công nhận trong GCN
# Gần chùa Linh Sơn (dưới 30m)
# Trên đất trồng bắp
# Đất trống trên đất có ao
# Bên hông giáp đường sắt Thống Nhất

# %%
# Clean the dataset
# df_cleaned = df.dropna(subset=features_all).copy()
# print(df_cleaned.shape)

# Preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ("num", StandardScaler(), features_numerical),
    ("cat", OneHotEncoder(handle_unknown="ignore"), features_categorical)
])

# Fit-transform the data
X_preprocessed = preprocessor.fit_transform(df)

# Store for next step
df_knn_ready = df.reset_index(drop=True)

X_preprocessed.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19452\2932472823.py in ?()
#       8     ("cat", OneHotEncoder(handle_unknown="ignore"), features_categorical)
#       9 ])
#      10
#      11 # Fit-transform the data
# ---> 12 X_preprocessed = preprocessor.fit_transform(df)
#      13
#      14 # Store for next step
#      15 df_knn_ready = df.reset_index(drop=True)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, **params)
#     997             routed_params = process_routing(self, "fit_transform", **params)
#     998         else:
#     999             routed_params = self._get_empty_routing()
#    1000
# -> 1001         result = self._call_func_on_transformers(
#    1002             X,
#    1003             y,
#    1004             _fit_transform_one,
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     908                 )
#     909
#     910             return Parallel(n_jobs=self.n_jobs)(jobs)
#     911
# --> 912         except ValueError as e:
#     913             if "Expected 2D array, got 1D array instead" in str(e):
#     914                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     915             else:
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, message_clsname, message, params)
#    1547     """
#    1548     params = params or {}
#    1549     with _print_elapsed_time(message_clsname, message):
#    1550         if hasattr(transformer, "fit_transform"):
# -> 1551             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552         else:
#    1553             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554                 X, **params.get("transform", {})
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     914                 )
#     915
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
#     921             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     890             Fitted scaler.
#     891         """
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     926         self : object
#     927             Fitted scaler.
#     928         """
#     929         first_call = not hasattr(self, "n_samples_seen_")
# --> 930         X = validate_data(
#     931             self,
#     932             X,
#     933             accept_sparse=("csr", "csc"),
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\Users\duongtq\AppData\Local\anaconda3\envs\general\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# TypeError: float() argument must be a string or a real number, not 'datetime.datetime'

# %%
df_knn_ready.shape
# Out:
# (4784, 15)

# %%
# Simulate a new TSTDG (property to be evaluated)
simulated_tstdg = {
    "area": 350.0,
    "width": 18.0,
    "height": 90.0,
    "percentQuality": 78.0,
    "landPrice": 0.0,  # Unknown — what we're trying to estimate
    "lat": 10.045,     # Near other properties
    "lon": 105.730,
    "legalStatus": "Có GCNQSDĐ",
    "shape": "Tương đối vuông vức",
    "other": "QH đất TMDV"
}

# Convert to DataFrame
tstdg_df = pd.DataFrame([simulated_tstdg])

# Apply the same preprocessing pipeline
tstdg_vector = preprocessor.transform(tstdg_df)

# Store for KNN search
tstdg_vector.shape
# Out:
# (1, 450)

# %%
from sklearn.neighbors import NearestNeighbors

# Filter database to only include reference properties (TSSS)
df_reference = df_knn_ready[df_knn_ready["isCompare"] == True].reset_index(drop=True)
X_reference = preprocessor.transform(df_reference[features_all])

# Run KNN
knn = NearestNeighbors(n_neighbors=3, metric='euclidean')
knn.fit(X_reference)
distances, indices = knn.kneighbors(tstdg_vector)

# Get top 3 similar properties
top_3_similar = df_reference.iloc[indices[0]].copy()
top_3_similar["similarity_score"] = distances[0]

# import ace_tools as tools; tools.display_dataframe_to_user(name="Top 3 KNN Reference Properties", dataframe=top_3_similar)
